# %% [markdown]
# ## Первичный анализ данных
#
# Анисимов Максим ИУ10-56, Вариант - 3, База данных - http://archive.ics.uci.edu/dataset/19/car+evaluation
#
# ### Цель работы
#
# Изучение программных средств для организации рабочего места специалиста по машинному обучению и анализу данных.
#
# ### Задачи
#
#  - получение программного доступа к данным, содержащимся в источниках различного типа;
#  - выполнение предварительного анализа данных и получение обобщенных характеристик наборов данных;
#  - исследование простых методов визуализации данных;
#  - изучение основных библиотек Python для работы с данными.
#
# ### Продолжительность и сроки сдачи
#
# Продолжительность работы: - 4 часа.
#
# Мягкий дедлайн (5 баллов): 10.10.2023
#
# Жесткий дедлайн (2.5 баллов): 24.10.2023
#
# ### 2.Теоретические сведения
#
# Датасет "Car Evaluation" доступен на сайте UCI Machine Learning Repository и содержит информацию о характеристиках автомобилей и их классификации по степени приемлемости для покупки. В этом разделе я предоставлю теоретические сведения о датасете "Car Evaluation":
#
# ### Описание набора данных:
# - Название: Car Evaluation
# - Описание: Данный набор данных содержит информацию о характеристиках автомобилей и их классификации на четыре уровня приемлемости: "unacceptable," "acceptable," "good," и "very good."
#
# ### Назначение набора данных:
# Цель: Главная цель этого набора данных - предоставить информацию для построения моделей, способных классифицировать автомобили по степени приемлемости для покупки на основе их характеристик. Это задание можно рассматривать как задачу классификации.
#
# Практические задачи, решаемые с использованием данных: На основе данных из этого набора можно решать следующие практические задачи:
#
# 1) Классификация автомобилей: Можно построить модель классификации, которая оценивает, насколько автомобиль приемлем для покупки, и присваивает ему одну из четырех категорий: "unacceptable," "acceptable," "good," или "very good."
# 2) Прогнозирование продаж и популярности автомобилей: Исследование данных о степени приемлемости автомобилей может помочь производителям автомобилей понять, какие характеристики автомобилей наиболее важны для потенциальных покупателей и, таким образом, предсказать популярность и продажи различных моделей.
# ### Описание признаков и их тип:
# - buying: Классификация цен на автомобили (категориальный).
# - maint: Классификация затрат на обслуживание автомобиля (категориальный).
# - doors: Количество дверей (категориальный).
# - persons: Количество сидячих мест в автомобиле (категориальный).
# - lug_boot: Размер багажника (категориальный).
# - safety: Уровень безопасности (категориальный).
# - class: Классификация приемлемости автомобиля (целевая переменная, категориальный).
#
# Этот набор данных представляет собой типичный пример задачи классификации, где целью является предсказание категории (класса) на основе входных признаков. Для обработки категориальных признаков в этом наборе данных, вероятно, потребуется использовать методы кодирования, такие как one-hot encoding.

# %% [markdown]
# ### 2.1 Описание набора данных:
# Набор данных представляет собой информацию о характеристиках автомобилей и их классификации по степени приемлемости для покупки. Данные могут использоваться для построения моделей, предсказывающих приемлемость автомобилей для покупки на основе их характеристик.
#
# ### Признаки (столбцы) в наборе данных:
#
# - buying: Классификация цен на автомобили (vhigh, high, med, low).
# - maint: Классификация затрат на обслуживание автомобиля (vhigh, high, med, low).
# - doors: Количество дверей (2, 3, 4, 5more).
# - persons: Количество сидячих мест в автомобиле (2, 4, more).
# - lug_boot: Размер багажника (small, med, big).
# - safety: Уровень безопасности (low, med, high).
# - class: Классификация приемлемости автомобиля (unacc, acc, good, vgood).
#
# ### 2.2 Форма набора данных:
# - Количество элементов в наборе данных: Для уточнения этой информации, нужно знать, сколько строк (наблюдений) содержится в вашем наборе данных.
# - Количество признаков: В наборе данных 7 признаков.
# - Количество пропущенных значений: Необходимо выполнить проверку на пропущенные значения с помощью функции isnull() или info().
# - Средние значения отдельных признаков: Для числовых признаков можно рассчитать средние значения с помощью метода mean().
# - Максимальные и минимальные значения отдельных признаков: Для числовых признаков можно рассчитать максимальные и минимальные значения с помощью методов max() и min().
#
# Предположения, которые можно сделать на данном этапе:
# - Вероятно, классификация class будет целевой переменной для задачи классификации.
# - Классы приемлемости автомобилей (class) могут быть несбалансированными, и это следует учитывать при построении моделей.
# - Для построения моделей могут потребоваться кодирование категориальных признаков (например, one-hot encoding).

# %%
data1 = np.genfromtxt(data_path, delimiter=",", dtype=None)
print('Shape of the dataset:', data1.shape)
print('Dataset type:', type(data1))
print('A single row of the dataset is type of:', type(data1[0]))
print('Types of elements:', type(data1[0][1]), type(data1[0][6]))
print('Dataset:')
print(data1)
# Out:
# Shape of the dataset: (1728, 7)
# Dataset type: <class 'numpy.ndarray'>
# A single row of the dataset is type of: <class 'numpy.ndarray'>
# Types of elements: <class 'numpy.bytes_'> <class 'numpy.bytes_'>
# Dataset:
# [[b'vhigh' b'vhigh' b'2' ... b'small' b'low' b'unacc']
#  [b'vhigh' b'vhigh' b'2' ... b'small' b'med' b'unacc']
#  [b'vhigh' b'vhigh' b'2' ... b'small' b'high' b'unacc']
#  ...
#  [b'low' b'low' b'5more' ... b'big' b'low' b'unacc']
#  [b'low' b'low' b'5more' ... b'big' b'med' b'good']
#  [b'low' b'low' b'5more' ... b'big' b'high' b'vgood']]
# C:\Users\maksi\AppData\Local\Temp\ipykernel_7128\4071036738.py:1: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#   data1 = np.genfromtxt(data_path, delimiter=",", dtype=None)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
data = pd.read_csv('datasets/car.data', header=None)
data.columns = ['buying', 'maint', 'doors', 'persons', 'lug_boot', 'safety', 'class']

# Describe the dataset
print("Dataset Description:")
print(data.head())
print("\nData Information:")
print(data.info())

# Statistical summary
print("\nStatistical Summary:")
print(data.describe())

# Histograms for categorical features
categorical_features = ['buying', 'maint', 'doors', 'persons', 'lug_boot', 'safety', 'class']
for feature in categorical_features:
    plt.figure(figsize=(8, 6))
    data[feature].value_counts().plot(kind='bar', color='skyblue')
    plt.title(f'Distribution of {feature}')
    plt.xlabel(feature)
    plt.ylabel('Count')
    plt.show()

# Scatter plot between two categorical features (example)
plt.figure(figsize=(8, 6))
plt.scatter(data['buying'], data['class'], c='blue', marker='o')
plt.title('Scatter plot between buying and class')
plt.xlabel('buying')
plt.ylabel('class')
plt.show()
# Out:
# Dataset Description:
#   buying  maint doors persons lug_boot safety  class
# 0  vhigh  vhigh     2       2    small    low  unacc
# 1  vhigh  vhigh     2       2    small    med  unacc
# 2  vhigh  vhigh     2       2    small   high  unacc
# 3  vhigh  vhigh     2       2      med    low  unacc
# 4  vhigh  vhigh     2       2      med    med  unacc
#
# Data Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1728 entries, 0 to 1727
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   buying    1728 non-null   object
#  1   maint     1728 non-null   object
#  2   doors     1728 non-null   object
#  3   persons   1728 non-null   object
#  4   lug_boot  1728 non-null   object
#  5   safety    1728 non-null   object
#  6   class     1728 non-null   object
# dtypes: object(7)
# memory usage: 94.6+ KB
# None
#
# Statistical Summary:
#        buying  maint doors persons lug_boot safety  class
# ...

# %% [markdown]
# # Контрольные вопросы
#
# ### Инструментальные средства для организации рабочего места специалиста Data Science:
#
#  - Python: Основной язык программирования в области Data Science. Имеет богатый выбор библиотек для анализа данных, машинного обучения и визуализации.
#
#  - Jupyter Notebook/JupyterLab: Интерактивная среда для создания и обмена документами, в которых можно выполнять код, делать заметки и визуализации.
#
#  - IDE (Integrated Development Environment): Различные IDE, такие как PyCharm, Visual Studio Code, Spyder, предоставляют удобную среду для написания, тестирования и отладки кода.
#
#  - Библиотеки анализа данных: Pandas, NumPy - для работы с данными и выполнения операций линейной алгебры.
#
#  - Библиотеки визуализации данных: Matplotlib, Seaborn, Plotly - для создания информативных визуализаций.
#
#  - Системы управления версиями: Git, GitHub - для контроля версий и совместной работы над проектами.
#
# ### Библиотеки Python для машинного обучения:
#
#  - Scikit-Learn:
#     Библиотека, предназначенная для обучения моделей машинного обучения. Включает в себя алгоритмы классификации, регрессии, кластеризации, а также инструменты для предобработки данных и оценки моделей.
#
#  - TensorFlow:
#     Фреймворк для глубокого обучения, разработанный Google. Позволяет строить и обучать нейронные сети, включая сверточные и рекуррентные.
#
#  - Keras:
#     Высокоуровневый API для работы с нейронными сетями, построенный поверх фреймворков, таких как TensorFlow и Theano. Облегчает создание и обучение моделей.
#
#  - PyTorch:
#     Фреймворк для глубокого обучения с открытым исходным кодом, разработанный Facebook. Имеет динамический вычислительный граф, что упрощает процесс экспериментирования и отладки моделей.
#
#  - XGBoost:
#     Реализация алгоритма градиентного бустинга. Используется для задач классификации, регрессии и ранжирования. Обеспечивает высокую производительность и эффективность.
#
#  - NLTK (Natural Language Toolkit):
#     Библиотека для обработки естественного языка, предназначенная для анализа текста и создания моделей обработки языка.
#
# ### Почему Python и его библиотеки широко распространены в машинном обучении:
#
#  - Простота и читаемость кода: Python имеет простой и интуитивно понятный синтаксис, что упрощает разработку и поддержку кода.
#
#  - Богатые библиотеки: Python имеет множество библиотек для анализа данных, машинного обучения, визуализации и других задач, что делает его мощным инструментом для специалистов Data Science.
#
#  - Активное сообщество: Сообщество разработчиков Python активно работает над улучшением языка и его библиотек, предоставляя обновления, дополнения и поддержку.
#
#  - Поддержка крупных организаций: Большие компании, такие как Google, Facebook, Microsoft, активно используют Python для разработки и исследований, поддерживая его развитие и распространение.
