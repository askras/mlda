# %% [markdown]
# ## Лабораторная работа №2
# ### Вариант 19
# ##### Студент: Чередова Александра
# ### Цель работы
# изучение программных средств для организации рабочего места специалиста по машинному обучению и анализу данных.
#
# ### Задачи
# - получение программного доступа к данным
# - содержащимся в источниках различного типа
# - выполнение предварительного анализа данных и получение обобщенных характеристик наборов данных
# - исследование простых методов визуализации данных
# - изучение основных библиотек Python для работы с данными

# %% [markdown]
# ## Housing Market & Prices

# %% [markdown]
# ![](./img/dataset-cover.jpg)

# %%
import numpy as np

data_path = "./datasets/house.data"
data = np.genfromtxt(data_path, delimiter=",", dtype=None)
print(data)


#bedroom_count,net_sqm,center_distance,metro_distance,floor,age,price
# Out:
# [(1,  26.18409786, 1286.68, 204.0038173 , 22, 67, 96004.80455672)
#  (1,  34.86690091, 1855.25, 186.98036042,  8, 30, 92473.72256806)
#  (1,  36.98070899,  692.09, 111.22499921, 24, 24, 98112.51994167) ...
#  (5, 299.56397219, 1585.37, 235.53788055,  3,  5, 93803.71561735)
#  (1,  29.19390676, 1896.23, 147.22382705,  4,  2, 92914.72912565)
#  (2,  54.4375727 ,  255.24,  25.52401985, 18,  0, 93743.04729235)]

# %%
dt = np.dtype("int, f8, f8, f8, int, int, f8")
data2 = np.genfromtxt(data_path, delimiter=",", dtype=dt)
print('Shape of the dataset:', data2.shape)
print('Number of cases:', data2.shape[0])
print('Dataset type:', type(data2))
print('A single row of the dataset is type of:', type(data2[0]))
print('Types of elements:', type(data2[0][1]), type(data2[0][4]))
print('Dataset slice:')
print(data2[:10])
# Out:
# Shape of the dataset: (4308,)
# Number of cases: 4308
# Dataset type: <class 'numpy.ndarray'>
# A single row of the dataset is type of: <class 'numpy.void'>
# Types of elements: <class 'numpy.float64'> <class 'numpy.int32'>
# Dataset slice:
# [(1, 26.18409786, 1286.68, 204.0038173 , 22, 67, 96004.80455672)
#  (1, 34.86690091, 1855.25, 186.98036042,  8, 30, 92473.72256806)
#  (1, 36.98070899,  692.09, 111.22499921, 24, 24, 98112.51994167)
#  (1, 17.44572314, 1399.49, 237.99875996,  1, 66, 92118.32687439)
#  (1, 52.58764598,   84.65, 100.99639951, 20,  3, 98976.65317569)
#  (1, 22.42558366, 1901.1 , 218.60342088,  6, 23, 91491.71410688)
#  (1, 33.03390008, 1833.94, 159.89365741, 21,  0, 93381.40943538)
#  (1, 27.8834803 , 1384.89, 145.1700251 , 14, 12, 93503.28460022)
#  (1, 69.76510032,  640.89, 130.39377535, 12, 18, 98708.32354823)
#  (1, 37.79624701, 1754.86, 195.98928626, 23, 80, 90417.77739343)]

# %% [markdown]
# ##### Количество элементов набора - 4308
# ##### Количество признаков - 7
# ##### Количество пропущенных значений - 0

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline


#bedroom_count,net_sqm,center_distance,metro_distance,floor,age,price
# Data from individual columns
# bedroom_count = [] # Количество спален ----- их будем угадывать
net_sqm = [] # Чистые квадратные метры
center_distance = [] # Расстояние до центра
metro_distance = [] # Расстояние до метро 
floor = [] # Этаж
age = [] # Возраст здания
price = [] # Цена

# Traversing the entire data2 collection
for dot in data2:
#   bedroom_count.append(dot[0])
    net_sqm.append(dot[1])
    center_distance.append(dot[2])
    metro_distance.append(dot[3])
    floor.append(dot[4])
    age.append(dot[5])  
    price.append(dot[6]) 
    
    

# Мы строим графики на основе проекций данных с учетом того, что число спален постепенно увеличивается
# Первая категория - от 1 до 3 спален
# Вторая - от 3 до 10
# Третья - более 10
plt.figure(1)

little, = plt.plot(net_sqm[:2100], price[:2100], 'ro', label='Мало спален')
Normal, = plt.plot(net_sqm[2100:3476], price[2100:3476], 'g^', label='Норм спален')
Large, = plt.plot(net_sqm[3476:3531], price[3476:3531], 'bs', label='Очень много спален')


plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.xlabel('net_sqm')
plt.ylabel('price')

plt.show()

# %%
plt.figure(2)

little, = plt.plot(center_distance[:2100], price[:2100], 'ro', label='Мало спален')
Normal, = plt.plot(center_distance[2100:3476], price[2100:3476], 'g^', label='Норм спален')
Large, = plt.plot(center_distance[3476:3531], price[3476:3531], 'bs', label='Очень много спален')


plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.xlabel('center_distance')
plt.ylabel('price')

plt.show()

# %%
plt.figure(3)

little, = plt.plot(age[:2100], price[:2100], 'ro', label='Мало спален')
Normal, = plt.plot(age[2100:3476], price[2100:3476], 'g^', label='Норм спален')
Large, = plt.plot(age[3476:3531], price[3476:3531], 'bs', label='Очень много спален')

plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.xlabel('age')
plt.ylabel('price')

plt.show()

# %%
plt.figure(4)
# Пример неподходящих атрибутов для решения данной задачи

little, = plt.plot(center_distance[:2100], metro_distance[:2100], 'ro', label='Мало спален')
Normal, = plt.plot(center_distance[2100:3476], metro_distance[2100:3476], 'g^', label='Норм спален')
Large, = plt.plot(center_distance[3476:3531], metro_distance[3476:3531], 'bs', label='Очень много спален')

plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.xlabel('center_distance')
plt.ylabel('metro_distance')

plt.show()
