# %% [markdown]
# ## Первичный анализ данных
#
# Стратиенко Илья ИУ10-56, Вариант - 17, База данных - https://archive.ics.uci.edu/dataset/10/automobile
#
# ### Цель работы
#
# Изучение программных средств для организации рабочего места специалиста по машинному обучению и анализу данных.
#
# ### Задачи
#
#  - получение программного доступа к данным, содержащимся в источниках различного типа;
#  - выполнение предварительного анализа данных и получение обобщенных характеристик наборов данных;
#  - исследование простых методов визуализации данных;
#  - изучение основных библиотек Python для работы с данными.
#
# ### Продолжительность и сроки сдачи
#
# Продолжительность работы: - 4 часа.
#
# Мягкий дедлайн (5 баллов): 10.10.2023
#
# Жесткий дедлайн (2.5 баллов): 24.10.2023
#
# ### 2.Теоретические сведения
#
# ### 2.1 Описание набора данных:
# Данный набор данных содержит информацию о различных характеристиках автомобилей и связанных с ними рейтингах страхового риска и нормализованных потерь по сравнению с другими автомобилями. Набор данных предназначен для анализа и может использоваться для построения различных моделей, таких как:
#
# Модели прогнозирования страховых рисков: Можно построить модели, которые предсказывают страховой риск автомобиля на основе его характеристик, таких как тип двигателя, размер двигателя, мощность и другие.
# Модели определения цены автомобиля: Набор данных содержит информацию о ценах автомобилей, и можно построить модели для оценки стоимости автомобиля на основе его характеристик.
#
#
# ### Назначение набора данных:
# Эта база данных может использоваться для решения различных практических задач и задач анализа данных. Ниже приведены некоторые из практических задач, которые можно решить, используя информацию из этой базы данных:
#
# Оценка страховых рисков: На основе данных о характеристиках автомобилей и страховых рейтингах можно разрабатывать модели для оценки страховых рисков конкретных автомобилей. Это поможет страховым компаниям определять страховые тарифы.
#
# Ценообразование на автомобили: Анализ цен на автомобили и их характеристик позволяет определить, какие факторы влияют на цену автомобиля. Это полезно для автопроизводителей и продавцов при установлении конкурентоспособных цен.
#
# Выбор автомобиля: Потенциальные покупатели могут использовать эту базу данных для сравнения различных автомобилей по характеристикам, цене и страховым рискам перед покупкой.
#
# Маркетинг и стратегическое планирование: Производители и маркетологи могут анализировать данные для разработки маркетинговых стратегий и определения, какие характеристики автомобилей пользуются наибольшей популярностью.
#
# ### Описание признаков и их тип:
# symboling: Категориальный (целочисленный) - оценка риска автомобиля.
# normalized-losses: Вещественный (непрерывный) - нормализованные потери по страхованию.
# make: Категориальный (строковый) - марка и модель автомобиля.
# fuel-type: Категориальный (строковый) - тип топлива (дизель или бензин).
# aspiration: Категориальный (строковый) - тип наддува (стандартный или турбо).
# num-of-doors: Категориальный (строковый) - количество дверей (четыре или две).
# body-style: Категориальный (строковый) - тип кузова (седан, хэтчбек и т. д.).
# drive-wheels: Категориальный (строковый) - тип привода (передний, задний, полный).
# engine-location: Категориальный (строковый) - расположение двигателя (переднее или заднее).
# wheel-base: Вещественный (непрерывный) - длина колесной базы.
# length: Вещественный (непрерывный) - длина автомобиля.
# width: Вещественный (непрерывный) - ширина автомобиля.
# height: Вещественный (непрерывный) - высота автомобиля.
# curb-weight: Вещественный (непрерывный) - масса автомобиля.
# engine-type: Категориальный (строковый) - тип двигателя (DOHC, OHCV и другие).
# num-of-cylinders: Категориальный (строковый) - количество цилиндров (четыре, шесть и другие).
# engine-size: Вещественный (непрерывный) - объем двигателя.
# fuel-system: Категориальный (строковый) - тип топливной системы.
# bore: Вещественный (непрерывный) - диаметр цилиндра.
# stroke: Вещественный (непрерывный) - ход поршня.
# compression-ratio: Вещественный (непрерывный) - степень сжатия.
# horsepower: Вещественный (непрерывный) - мощность двигателя.
# peak-rpm: Вещественный (непрерывный) - пиковая частота вращения двигателя.
# city-mpg: Вещественный (непрерывный) - расход топлива в городе.
# highway-mpg: Вещественный (непрерывный) - расход топлива на шоссе.
# price: Вещественный (непрерывный) - цена автомобиля.
#
# ### 2.2 Форма набора данных:
# Количество элементов набора данных: Это зависит от размера файла с данными.
# Количество признаков: 26 признаков, как указано выше.
# Количество пропущенных значений: Это зависит от конкретного набора данных. Необходимо выполнить анализ данных, чтобы найти пропущенные значения.
# Средние значения отдельных признаков: Это зависит от конкретного набора данных и может быть найдено с использованием метода describe() для каждого признака.
# Максимальные и минимальные значения отдельных признаков: Это также зависит от конкретного набора данных и может быть найдено с использованием метода describe() для каждого признака.
# Предположения: В рамках первичного анализа данных можно предположить, что некоторые признаки, такие как цена, мощность двигателя и объем двигателя, будут важными при оценке страхового риска и цены автомобиля. Также стоит предположить, что категориальные признаки, такие как марка автомобиля, тип кузова и топливная система, могут влиять на страховой риск и цену.

# %%
import numpy as np
data_path = "./data/imports-85.data"

# %%
import numpy as np

# Load the data
data1 = np.genfromtxt('./data/imports-85.data', delimiter=",", dtype=None, encoding=None)

# Shape of the dataset
print('Shape of the dataset:', data1.shape)

# Dataset type
print('Dataset type:', type(data1))

# Type of a single row
print('A single row of the dataset is type of:', type(data1[0]))

# Types of elements
print('Types of elements:', type(data1[0][1]), type(data1[0][10]))

# Display the dataset
print('Dataset:')
print(data1)
# Out:
# Shape of the dataset: (205,)
# Dataset type: <class 'numpy.ndarray'>
# A single row of the dataset is type of: <class 'numpy.void'>
# Types of elements: <class 'numpy.str_'> <class 'numpy.float64'>
# Dataset:
# [( 3, '?', 'alfa-romero', 'gas', 'std', 'two', 'convertible', 'rwd', 'front',  88.6, 168.8, 64.1, 48.8, 2548, 'dohc', 'four', 130, 'mpfi', '3.47', '2.68',  9.  , '111', '5000', 21, 27, '13495')
#  ( 3, '?', 'alfa-romero', 'gas', 'std', 'two', 'convertible', 'rwd', 'front',  88.6, 168.8, 64.1, 48.8, 2548, 'dohc', 'four', 130, 'mpfi', '3.47', '2.68',  9.  , '111', '5000', 21, 27, '16500')
#  ( 1, '?', 'alfa-romero', 'gas', 'std', 'two', 'hatchback', 'rwd', 'front',  94.5, 171.2, 65.5, 52.4, 2823, 'ohcv', 'six', 152, 'mpfi', '2.68', '3.47',  9.  , '154', '5000', 19, 26, '16500')
#  ( 2, '164', 'audi', 'gas', 'std', 'four', 'sedan', 'fwd', 'front',  99.8, 176.6, 66.2, 54.3, 2337, 'ohc', 'four', 109, 'mpfi', '3.19', '3.40', 10.  , '102', '5500', 24, 30, '13950')
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('./data/imports-85.data', header=None)

data.columns = ['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration', 'num-of-doors', 
                'body-style', 'drive-wheels', 'engine-location', 'wheel-base', 'length', 'width', 'height',
                'curb-weight', 'engine-type', 'num-of-cylinders', 'engine-size', 'fuel-system', 'bore',
                'stroke', 'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg', 'highway-mpg', 'price']

# Вывод описания набора данных
print("Dataset Description:")
print(data.head())
print("\nData Information:")
print(data.info())

# Статистическое описание данных
print("\nStatistical Summary:")
print(data.describe())

# Гистограммы для категориальных признаков
categorical_features = ['make', 'fuel-type', 'aspiration', 'num-of-doors', 'body-style',
                       'drive-wheels', 'engine-location', 'engine-type', 'num-of-cylinders', 'fuel-system']
for feature in categorical_features:
    plt.figure(figsize=(8, 6))
    data[feature].value_counts().plot(kind='bar', color='skyblue')
    plt.title(f'Distribution of {feature}')
    plt.xlabel(feature)
    plt.ylabel('Count')
    plt.show()

# Диаграмма рассеяния между двумя числовыми признаками (пример)
plt.figure(figsize=(8, 6))
plt.scatter(data['engine-size'], data['horsepower'], c='blue', marker='o')
plt.title('Scatter plot between engine-size and horsepower')
plt.xlabel('engine-size')
plt.ylabel('horsepower')
plt.show()
# Out:
# Dataset Description:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %% [markdown]
# # Контрольные вопросы
#
# ### Инструментальные средства для организации рабочего места специалиста Data Science:
#
#  - Python: Основной язык программирования в области Data Science. Имеет богатый выбор библиотек для анализа данных, машинного обучения и визуализации.
#
#  - Jupyter Notebook/JupyterLab: Интерактивная среда для создания и обмена документами, в которых можно выполнять код, делать заметки и визуализации.
#
#  - IDE (Integrated Development Environment): Различные IDE, такие как PyCharm, Visual Studio Code, Spyder, предоставляют удобную среду для написания, тестирования и отладки кода.
#
#  - Библиотеки анализа данных: Pandas, NumPy - для работы с данными и выполнения операций линейной алгебры.
#
#  - Библиотеки визуализации данных: Matplotlib, Seaborn, Plotly - для создания информативных визуализаций.
#
#  - Системы управления версиями: Git, GitHub - для контроля версий и совместной работы над проектами.
#
# ### Библиотеки Python для машинного обучения:
#
#  - Scikit-Learn:
#     Библиотека, предназначенная для обучения моделей машинного обучения. Включает в себя алгоритмы классификации, регрессии, кластеризации, а также инструменты для предобработки данных и оценки моделей.
#
#  - TensorFlow:
#     Фреймворк для глубокого обучения, разработанный Google. Позволяет строить и обучать нейронные сети, включая сверточные и рекуррентные.
#
#  - Keras:
#     Высокоуровневый API для работы с нейронными сетями, построенный поверх фреймворков, таких как TensorFlow и Theano. Облегчает создание и обучение моделей.
#
#  - PyTorch:
#     Фреймворк для глубокого обучения с открытым исходным кодом, разработанный Facebook. Имеет динамический вычислительный граф, что упрощает процесс экспериментирования и отладки моделей.
#
#  - XGBoost:
#     Реализация алгоритма градиентного бустинга. Используется для задач классификации, регрессии и ранжирования. Обеспечивает высокую производительность и эффективность.
#
#  - NLTK (Natural Language Toolkit):
#     Библиотека для обработки естественного языка, предназначенная для анализа текста и создания моделей обработки языка.
#
# ### Почему Python и его библиотеки широко распространены в машинном обучении:
#
#  - Простота и читаемость кода: Python имеет простой и интуитивно понятный синтаксис, что упрощает разработку и поддержку кода.
#
#  - Богатые библиотеки: Python имеет множество библиотек для анализа данных, машинного обучения, визуализации и других задач, что делает его мощным инструментом для специалистов Data Science.
#
#  - Активное сообщество: Сообщество разработчиков Python активно работает над улучшением языка и его библиотек, предоставляя обновления, дополнения и поддержку.
#
#  - Поддержка крупных организаций: Большие компании, такие как Google, Facebook, Microsoft, активно используют Python для разработки и исследований, поддерживая его развитие и распространение.
